# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Load Dataset

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/breast-cancer-wisconsin-data/data.csv

# %%
df = pd.read_csv('/kaggle/input/breast-cancer-wisconsin-data/data.csv')
df.shape
# Out:
# (569, 33)

# %% [markdown]
# ## Data Cleaning

# %%
# drop irrelavant column
df.drop(columns=['Unnamed: 32','id'],inplace=True)
df.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0         0.2419  ...         25.38          17.33           184.60
# 1         0.1812  ...         24.99          23.41           158.80
# 2         0.2069  ...         23.57          25.53           152.50
# 3         0.2597  ...         14.91          26.50            98.87
# 4         0.1809  ...         22.54          16.67           152.20
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 31 columns]

# %%
# check null value
df.isna().sum()
# Out:
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# dtype: int64

# %%
# check datatypes
df.dtypes
# Out:
# diagnosis                   object
# radius_mean                float64
# texture_mean               float64
# perimeter_mean             float64
# area_mean                  float64
# smoothness_mean            float64
# compactness_mean           float64
# concavity_mean             float64
# concave points_mean        float64
# symmetry_mean              float64
# fractal_dimension_mean     float64
# radius_se                  float64
# texture_se                 float64
# perimeter_se               float64
# area_se                    float64
# smoothness_se              float64
# compactness_se             float64
# concavity_se               float64
# concave points_se          float64
# symmetry_se                float64
# fractal_dimension_se       float64
# radius_worst               float64
# texture_worst              float64
# perimeter_worst            float64
# area_worst                 float64
# smoothness_worst           float64
# compactness_worst          float64
# concavity_worst            float64
# concave points_worst       float64
# symmetry_worst             float64
# fractal_dimension_worst    float64
# dtype: object

# %%
df['diagnosis'].replace({'B':0, 'M':1}, inplace=True)
df.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1        17.99         10.38          122.80     1001.0
# 1          1        20.57         17.77          132.90     1326.0
# 2          1        19.69         21.25          130.00     1203.0
# 3          1        11.42         20.38           77.58      386.1
# 4          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0         0.2419  ...         25.38          17.33           184.60
# 1         0.1812  ...         24.99          23.41           158.80
# 2         0.2069  ...         23.57          25.53           152.50
# 3         0.2597  ...         14.91          26.50            98.87
# 4         0.1809  ...         22.54          16.67           152.20
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 31 columns]

# %%
# a bit imbalanced
df['diagnosis'].value_counts()
# Out:
# 0    357
# 1    212
# Name: diagnosis, dtype: int64

# %% [markdown]
# ## Data Scaling

# %%
cols_to_scale = list(df.columns)
cols_to_scale.remove('diagnosis')

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df[cols_to_scale] = scaler.fit_transform(df[cols_to_scale])
df.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1     0.521037      0.022658        0.545989   0.363733
# 1          1     0.643144      0.272574        0.615783   0.501591
# 2          1     0.601496      0.390260        0.595743   0.449417
# 3          1     0.210090      0.360839        0.233501   0.102906
# 4          1     0.629893      0.156578        0.630986   0.489290
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0         0.593753          0.792037        0.703140             0.731113
# 1         0.289880          0.181768        0.203608             0.348757
# 2         0.514309          0.431017        0.462512             0.635686
# 3         0.811321          0.811361        0.565604             0.522863
# 4         0.430351          0.347893        0.463918             0.518390
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0       0.686364  ...      0.620776       0.141525         0.668310
# 1       0.379798  ...      0.606901       0.303571         0.539818
# 2       0.509596  ...      0.556386       0.360075         0.508442
# 3       0.776263  ...      0.248310       0.385928         0.241347
# 4       0.378283  ...      0.519744       0.123934         0.506948
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0    0.450698          0.601136           0.619292         0.568610
# 1    0.435214          0.347553           0.154563         0.192971
# 2    0.374508          0.483590           0.385375         0.359744
# 3    0.094008          0.915472           0.814012         0.548642
# 4    0.341575          0.437364           0.172415         0.319489
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 0              0.912027        0.598462                 0.418864
# 1              0.639175        0.233590                 0.222878
# 2              0.835052        0.403706                 0.213433
# 3              0.884880        1.000000                 0.773711
# 4              0.558419        0.157500                 0.142595
#
# [5 rows x 31 columns]

# %%
X = df.drop('diagnosis',axis='columns')
y = df['diagnosis']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=5)

# %% [markdown]
# ## Build a ANN

# %%
import tensorflow as tf
from tensorflow import keras

model = keras.Sequential([
    keras.layers.Dense(64, input_shape=(30,), activation="relu"),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(16,activation="relu"),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(1, activation="sigmoid")
])
model.compile(optimizer="adam", loss="binary_crossentropy", metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 64)                1984
#
#  dropout_4 (Dropout)         (None, 64)                0
#
#  dense_7 (Dense)             (None, 16)                1040
#
#  dropout_5 (Dropout)         (None, 16)                0
#
#  dense_8 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 3,041
# Trainable params: 3,041
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stop = EarlyStopping(monitor='val_loss', patience=10)

history = model.fit(X_train, y_train, epochs=100, validation_data=(X_test,y_test), callbacks=[early_stop])
# Out:
# Epoch 1/100
# 15/15 [==============================] - 1s 16ms/step - loss: 0.6768 - accuracy: 0.5736 - val_loss: 0.6489 - val_accuracy: 0.8596
# Epoch 2/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.6388 - accuracy: 0.7912 - val_loss: 0.6134 - val_accuracy: 0.8684
# Epoch 3/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.5998 - accuracy: 0.8418 - val_loss: 0.5680 - val_accuracy: 0.9123
# Epoch 4/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.5572 - accuracy: 0.8505 - val_loss: 0.5235 - val_accuracy: 0.8947
# Epoch 5/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.5072 - accuracy: 0.8593 - val_loss: 0.4495 - val_accuracy: 0.8947
# Epoch 6/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.4487 - accuracy: 0.8659 - val_loss: 0.3833 - val_accuracy: 0.9035
# Epoch 7/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.3867 - accuracy: 0.8725 - val_loss: 0.3275 - val_accuracy: 0.9123
# Epoch 8/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.3473 - accuracy: 0.8879 - val_loss: 0.2908 - val_accuracy: 0.9035
# Epoch 9/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.3068 - accuracy: 0.8967 - val_loss: 0.2563 - val_accuracy: 0.9211
# Epoch 10/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.2792 - accuracy: 0.8989 - val_loss: 0.2389 - val_accuracy: 0.9211
# Epoch 11/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.2550 - accuracy: 0.9121 - val_loss: 0.2143 - val_accuracy: 0.9298
# Epoch 12/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.2261 - accuracy: 0.9275 - val_loss: 0.2120 - val_accuracy: 0.9211
# Epoch 13/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.2093 - accuracy: 0.9209 - val_loss: 0.1871 - val_accuracy: 0.9298
# Epoch 14/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1948 - accuracy: 0.9297 - val_loss: 0.1883 - val_accuracy: 0.9211
# Epoch 15/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1888 - accuracy: 0.9297 - val_loss: 0.1694 - val_accuracy: 0.9298
# Epoch 16/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1893 - accuracy: 0.9275 - val_loss: 0.1691 - val_accuracy: 0.9386
# Epoch 17/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1693 - accuracy: 0.9275 - val_loss: 0.1615 - val_accuracy: 0.9386
# Epoch 18/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1552 - accuracy: 0.9473 - val_loss: 0.1505 - val_accuracy: 0.9298
# Epoch 19/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1727 - accuracy: 0.9297 - val_loss: 0.1479 - val_accuracy: 0.9386
# Epoch 20/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1537 - accuracy: 0.9297 - val_loss: 0.1453 - val_accuracy: 0.9386
# Epoch 21/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1512 - accuracy: 0.9429 - val_loss: 0.1340 - val_accuracy: 0.9474
# Epoch 22/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1366 - accuracy: 0.9407 - val_loss: 0.1334 - val_accuracy: 0.9386
# Epoch 23/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1360 - accuracy: 0.9516 - val_loss: 0.1229 - val_accuracy: 0.9649
# Epoch 24/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1248 - accuracy: 0.9516 - val_loss: 0.1319 - val_accuracy: 0.9386
# Epoch 25/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1348 - accuracy: 0.9516 - val_loss: 0.1166 - val_accuracy: 0.9737
# Epoch 26/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1373 - accuracy: 0.9538 - val_loss: 0.1210 - val_accuracy: 0.9474
# Epoch 27/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1335 - accuracy: 0.9451 - val_loss: 0.1229 - val_accuracy: 0.9474
# Epoch 28/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1036 - accuracy: 0.9604 - val_loss: 0.1084 - val_accuracy: 0.9737
# Epoch 29/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1113 - accuracy: 0.9670 - val_loss: 0.1211 - val_accuracy: 0.9474
# Epoch 30/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1127 - accuracy: 0.9714 - val_loss: 0.1054 - val_accuracy: 0.9825
# Epoch 31/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1166 - accuracy: 0.9560 - val_loss: 0.1142 - val_accuracy: 0.9474
# Epoch 32/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1014 - accuracy: 0.9626 - val_loss: 0.0986 - val_accuracy: 0.9825
# Epoch 33/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1141 - accuracy: 0.9538 - val_loss: 0.1174 - val_accuracy: 0.9474
# Epoch 34/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0991 - accuracy: 0.9604 - val_loss: 0.0988 - val_accuracy: 0.9825
# Epoch 35/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1040 - accuracy: 0.9670 - val_loss: 0.1064 - val_accuracy: 0.9561
# Epoch 36/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0967 - accuracy: 0.9648 - val_loss: 0.0931 - val_accuracy: 0.9825
# Epoch 37/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0903 - accuracy: 0.9692 - val_loss: 0.1143 - val_accuracy: 0.9474
# Epoch 38/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1021 - accuracy: 0.9604 - val_loss: 0.0889 - val_accuracy: 0.9825
# Epoch 39/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0932 - accuracy: 0.9648 - val_loss: 0.0967 - val_accuracy: 0.9737
# Epoch 40/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0816 - accuracy: 0.9780 - val_loss: 0.0908 - val_accuracy: 0.9825
# Epoch 41/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0777 - accuracy: 0.9758 - val_loss: 0.1029 - val_accuracy: 0.9649
# Epoch 42/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0723 - accuracy: 0.9736 - val_loss: 0.0919 - val_accuracy: 0.9825
# Epoch 43/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0823 - accuracy: 0.9736 - val_loss: 0.0898 - val_accuracy: 0.9825
# Epoch 44/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0826 - accuracy: 0.9648 - val_loss: 0.0915 - val_accuracy: 0.9825
# Epoch 45/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0865 - accuracy: 0.9670 - val_loss: 0.0926 - val_accuracy: 0.9825
# Epoch 46/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0807 - accuracy: 0.9758 - val_loss: 0.0949 - val_accuracy: 0.9737
# Epoch 47/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0742 - accuracy: 0.9736 - val_loss: 0.0919 - val_accuracy: 0.9825
# Epoch 48/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0675 - accuracy: 0.9824 - val_loss: 0.0854 - val_accuracy: 0.9825
# Epoch 49/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0719 - accuracy: 0.9758 - val_loss: 0.0979 - val_accuracy: 0.9649
# Epoch 50/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0745 - accuracy: 0.9692 - val_loss: 0.0863 - val_accuracy: 0.9825
# Epoch 51/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0701 - accuracy: 0.9824 - val_loss: 0.0902 - val_accuracy: 0.9825
# Epoch 52/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0624 - accuracy: 0.9824 - val_loss: 0.0921 - val_accuracy: 0.9737
# Epoch 53/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0691 - accuracy: 0.9824 - val_loss: 0.0881 - val_accuracy: 0.9825
# Epoch 54/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0592 - accuracy: 0.9802 - val_loss: 0.0902 - val_accuracy: 0.9825
# Epoch 55/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0636 - accuracy: 0.9714 - val_loss: 0.0889 - val_accuracy: 0.9825
# Epoch 56/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0574 - accuracy: 0.9802 - val_loss: 0.0890 - val_accuracy: 0.9825
# Epoch 57/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0629 - accuracy: 0.9780 - val_loss: 0.0958 - val_accuracy: 0.9737
# Epoch 58/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0675 - accuracy: 0.9714 - val_loss: 0.0800 - val_accuracy: 0.9825
# Epoch 59/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0751 - accuracy: 0.9780 - val_loss: 0.0954 - val_accuracy: 0.9737
# Epoch 60/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0627 - accuracy: 0.9824 - val_loss: 0.0823 - val_accuracy: 0.9825
# Epoch 61/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0532 - accuracy: 0.9824 - val_loss: 0.0842 - val_accuracy: 0.9825
# Epoch 62/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0648 - accuracy: 0.9802 - val_loss: 0.0858 - val_accuracy: 0.9825
# Epoch 63/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0511 - accuracy: 0.9802 - val_loss: 0.0804 - val_accuracy: 0.9825
# Epoch 64/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0742 - accuracy: 0.9692 - val_loss: 0.0855 - val_accuracy: 0.9825
# Epoch 65/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0756 - accuracy: 0.9714 - val_loss: 0.0892 - val_accuracy: 0.9825
# Epoch 66/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0512 - accuracy: 0.9802 - val_loss: 0.0830 - val_accuracy: 0.9825
# Epoch 67/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0515 - accuracy: 0.9846 - val_loss: 0.0873 - val_accuracy: 0.9825
# Epoch 68/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0488 - accuracy: 0.9846 - val_loss: 0.0848 - val_accuracy: 0.9825

# %%
s, (at, al) = plt.subplots(2,1)
at.plot(history.history['accuracy'], c= 'b')
at.plot(history.history['val_accuracy'], c='r')
at.set_title('model accuracy')
at.set_ylabel('accuracy')
at.legend(['train', 'val'], loc='upper left')

al.plot(history.history['loss'], c='m')
al.plot(history.history['val_loss'], c='c')
al.set_title('model loss')
al.set_ylabel('loss')
al.set_xlabel('epoch')
al.legend(['train', 'val'], loc = 'upper left')
